# %% [markdown]
# # SpaceX API Data Collection Lab
#
# In this lab, we will collect data from the SpaceX API and process it for analysis.

# %%
import requests
import pandas as pd
import numpy as np

# %%
# Make a GET request to the SpaceX API
url = "https://api.spacexdata.com/v4/launches/past"
response = requests.get(url)
data = response.json()

# %%
# Convert JSON to dataframe
df = pd.json_normalize(data)

# %%
# Filter for Falcon 9 launches
df = df[df['rocket.name'] == 'Falcon 9']

# Calculate mean of PayloadMass
mean_payload_mass = df['payloads.0.mass_kg'].mean()

# Replace NULL values in PayloadMass with the mean
df['payloads.0.mass_kg'].fillna(mean_payload_mass, inplace=True)

# Keep LandingPad as NULL when not used
# This is already handled as the data comes with NULL values for unused landing pads
